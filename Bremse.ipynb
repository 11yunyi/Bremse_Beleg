# %%
import numpy as np
import matplotlib.pyplot as plt
ergbs_Ver1=np.loadtxt('Bremse2019-12-17_002.txt')

# %%
x1=ergbs_Ver1[:,0]
y1=ergbs_Ver1[:,4]

plt.plot(x1,y1)
plt.xlabel('Zeit[s]')
plt.ylabel('Versuch1 Drehzahl[U/min]')
plt.savefig('Versuch1_Drehzahl')
plt.show()

# %%
Zeit=ergbs_Ver1[:,0]
T1=ergbs_Ver1[:,5]
T2=ergbs_Ver1[:,6]
T3=ergbs_Ver1[:,7]
T4=ergbs_Ver1[:,8]
plt.title('Versuch2 Temperatursverlaufe')
l1=plt.plot(Zeit,T1,label='Temperatur 1')
l2=plt.plot(Zeit,T2,label='Temperatur 2')
l3=plt.plot(Zeit,T3,label='Temperatur 3')
l4=plt.plot(Zeit,T4,label='Temperatur 4')
plt.legend()
plt.show()

# %%
Zeit=ergbs_Ver1[:,0]
Drehzahl=ergbs_Ver1[:,4]
Bremsmoment=ergbs_Ver1[:,1]
Zugkraft=ergbs_Ver1[:,2]
#Zeitpunkt=[13.550,14.200,69.560,70.180,101.755,102.390,146.865,147.680,180.250,181.075,214.420,215.265,252.640,253.670,286.650,287.620,319.625,320.660,357.145,358.335,393.595,394.835,427.975,429.265]
#Zeitpunkt=[46.765,47.915,81.335,82.480,114.970,116.110,158.315,159.840,198.735,200.205,238.230,239.685,272.835,274.665,307.030,308.875,342.225,344.040,381.485,383.650,415.375,417.510,451.070,453.175]
Zeitpunkt=[14.000,14.600]
Zeitpunkt=[47.850,48.5]
j=0
Zeitpunktreihe=[]
for i in range(len(Zeit)):
    if Zeit[i]==Zeitpunkt[j]:
        Zeitpunktreihe.append(i)
        if j!=len(Zeitpunkt)-1:
            j+=1
    
Bremse_Zeit1=Zeit[Zeitpunktreihe[0]:Zeitpunktreihe[1]]
Anfangszeit1=np.ones(len(Bremse_Zeit1))*Zeit[Zeitpunktreihe[0]]
Bremsvorgangszeit1=Bremse_Zeit1-Anfangszeit1
Bremse_Drehzahl1=Drehzahl[Zeitpunktreihe[0]:Zeitpunktreihe[1]]
Bremsmoment1=Bremsmoment[Zeitpunktreihe[0]:Zeitpunktreihe[1]]
Zugkraft1=Zugkraft[Zeitpunktreihe[0]:Zeitpunktreihe[1]]

"""Bremse_Zeit2=Zeit[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Anfangszeit2=np.ones(len(Bremse_Zeit2))*Zeit[Zeitpunktreihe[2]]
Bremsvorgangszeit2=Bremse_Zeit2-Anfangszeit2
Bremse_Drehzahl2=Drehzahl[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Bremsmoment2=Bremsmoment[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Zugkraft2=Zugkraft[Zeitpunktreihe[2]:Zeitpunktreihe[3]]



Bremse_Zeit3=Zeit[Zeitpunktreihe[4]:Zeitpunktreihe[5]]
Anfangszeit3=np.ones(len(Bremse_Zeit3))*Zeit[Zeitpunktreihe[4]]
Bremsvorgangszeit3=Bremse_Zeit3-Anfangszeit3
Bremse_Drehzahl3=Drehzahl[Zeitpunktreihe[4]:Zeitpunktreihe[5]]
Bremsmoment3=Bremsmoment[Zeitpunktreihe[4]:Zeitpunktreihe[5]]
Zugkraft3=Zugkraft[Zeitpunktreihe[4]:Zeitpunktreihe[5]]

Bremse_Zeit4=Zeit[Zeitpunktreihe[6]:Zeitpunktreihe[7]]
Anfangszeit4=np.ones(len(Bremse_Zeit4))*Zeit[Zeitpunktreihe[6]]
Bremsvorgangszeit4=Bremse_Zeit4-Anfangszeit4
Bremse_Drehzahl4=Drehzahl[Zeitpunktreihe[6]:Zeitpunktreihe[7]]
Bremsmoment4=Bremsmoment[Zeitpunktreihe[6]:Zeitpunktreihe[7]]
Zugkraft4=Zugkraft[Zeitpunktreihe[6]:Zeitpunktreihe[7]]

Bremse_Zeit5=Zeit[Zeitpunktreihe[8]:Zeitpunktreihe[9]]
Anfangszeit5=np.ones(len(Bremse_Zeit5))*Zeit[Zeitpunktreihe[8]]
Bremsvorgangszeit5=Bremse_Zeit5-Anfangszeit5
Bremse_Drehzahl5=Drehzahl[Zeitpunktreihe[8]:Zeitpunktreihe[9]]
Bremsmoment5=Bremsmoment[Zeitpunktreihe[8]:Zeitpunktreihe[9]]
Zugkraft5=Zugkraft[Zeitpunktreihe[8]:Zeitpunktreihe[9]]

Bremse_Zeit6=Zeit[Zeitpunktreihe[10]:Zeitpunktreihe[11]]
Anfangszeit6=np.ones(len(Bremse_Zeit6))*Zeit[Zeitpunktreihe[10]]
Bremsvorgangszeit6=Bremse_Zeit6-Anfangszeit6
Bremse_Drehzahl6=Drehzahl[Zeitpunktreihe[10]:Zeitpunktreihe[11]]
Bremsmoment6=Bremsmoment[Zeitpunktreihe[10]:Zeitpunktreihe[11]]
Zugkraft6=Zugkraft[Zeitpunktreihe[10]:Zeitpunktreihe[11]]

Bremse_Zeit7=Zeit[Zeitpunktreihe[12]:Zeitpunktreihe[13]]
Anfangszeit7=np.ones(len(Bremse_Zeit7))*Zeit[Zeitpunktreihe[12]]
Bremsvorgangszeit7=Bremse_Zeit7-Anfangszeit7
Bremse_Drehzahl7=Drehzahl[Zeitpunktreihe[12]:Zeitpunktreihe[13]]
Bremsmoment7=Bremsmoment[Zeitpunktreihe[12]:Zeitpunktreihe[13]]
Zugkraft7=Zugkraft[Zeitpunktreihe[12]:Zeitpunktreihe[13]]

Bremse_Zeit8=Zeit[Zeitpunktreihe[14]:Zeitpunktreihe[15]]
Anfangszeit8=np.ones(len(Bremse_Zeit8))*Zeit[Zeitpunktreihe[14]]
Bremsvorgangszeit8=Bremse_Zeit8-Anfangszeit8
Bremse_Drehzahl8=Drehzahl[Zeitpunktreihe[14]:Zeitpunktreihe[15]]
Bremsmoment8=Bremsmoment[Zeitpunktreihe[14]:Zeitpunktreihe[15]]
Zugkraft8=Zugkraft[Zeitpunktreihe[14]:Zeitpunktreihe[15]]

Bremse_Zeit9=Zeit[Zeitpunktreihe[16]:Zeitpunktreihe[17]]
Anfangszeit9=np.ones(len(Bremse_Zeit9))*Zeit[Zeitpunktreihe[16]]
Bremsvorgangszeit9=Bremse_Zeit9-Anfangszeit9
Bremse_Drehzahl9=Drehzahl[Zeitpunktreihe[16]:Zeitpunktreihe[17]]
Bremsmoment9=Bremsmoment[Zeitpunktreihe[16]:Zeitpunktreihe[17]]
Zugkraft9=Zugkraft[Zeitpunktreihe[16]:Zeitpunktreihe[17]]

Bremse_Zeit10=Zeit[Zeitpunktreihe[18]:Zeitpunktreihe[19]]
Anfangszeit10=np.ones(len(Bremse_Zeit10))*Zeit[Zeitpunktreihe[18]]
Bremsvorgangszeit10=Bremse_Zeit10-Anfangszeit10
Bremse_Drehzahl10=Drehzahl[Zeitpunktreihe[18]:Zeitpunktreihe[19]]
Bremsmoment10=Bremsmoment[Zeitpunktreihe[18]:Zeitpunktreihe[19]]
Zugkraft10=Zugkraft[Zeitpunktreihe[18]:Zeitpunktreihe[19]]

Bremse_Zeit11=Zeit[Zeitpunktreihe[20]:Zeitpunktreihe[21]]
Anfangszeit11=np.ones(len(Bremse_Zeit11))*Zeit[Zeitpunktreihe[20]]
Bremsvorgangszeit11=Bremse_Zeit11-Anfangszeit11
Bremse_Drehzahl11=Drehzahl[Zeitpunktreihe[20]:Zeitpunktreihe[21]]
Bremsmoment11=Bremsmoment[Zeitpunktreihe[20]:Zeitpunktreihe[21]]
Zugkraft11=Zugkraft[Zeitpunktreihe[20]:Zeitpunktreihe[21]]

Bremse_Zeit12=Zeit[Zeitpunktreihe[22]:Zeitpunktreihe[23]]
Anfangszeit12=np.ones(len(Bremse_Zeit12))*Zeit[Zeitpunktreihe[22]]
Bremsvorgangszeit12=Bremse_Zeit12-Anfangszeit12
Bremse_Drehzahl12=Drehzahl[Zeitpunktreihe[22]:Zeitpunktreihe[23]]
Bremsmoment12=Bremsmoment[Zeitpunktreihe[22]:Zeitpunktreihe[23]]
Zugkraft12=Zugkraft[Zeitpunktreihe[22]:Zeitpunktreihe[23]]"""

plt.xlabel('Zeit[s]')
#plt.ylabel('Drehzahl[U/min]')
#plt.ylabel('Zugkraft[kN]')
plt.ylabel('Bremsmoment[V]')
#plt.title('Versuch1 Drehzahl bei Bremsvorgange')
#plt.title('Versuch2 Zugkraft bei Bremsvorgange')
#plt.title('Versuch2 Zugkraft bei Bremsvorgange')
#l1=plt.plot(Bremsvorgangszeit1,Bremse_Drehzahl1,label='Versuch1 750U/min')
#l2=plt.plot(Bremsvorgangszeit2,Bremse_Drehzahl2,label='Versuch2 750U/min')
#l3=plt.plot(Bremsvorgangszeit3,Bremse_Drehzahl3,label='Versuch3 750U/min')
#l4=plt.plot(Bremsvorgangszeit4,Bremse_Drehzahl4,label='Versuch1 1000U/min')
#l5=plt.plot(Bremsvorgangszeit5,Bremse_Drehzahl5,label='Versuch2 1000U/min')
#l6=plt.plot(Bremsvorgangszeit6,Bremse_Drehzahl6,label='Versuch3 1000U/min')
#l7=plt.plot(Bremsvorgangszeit7,Bremse_Drehzahl7,label='Versuch1 1200U/min')
#l8=plt.plot(Bremsvorgangszeit8,Bremse_Drehzahl8,label='Versuch2 1200U/min')
#l9=plt.plot(Bremsvorgangszeit9,Bremse_Drehzahl9,label='Versuch3 1200U/min')
#l10=plt.plot(Bremsvorgangszeit10,Bremse_Drehzahl10,label='Versuch1 1500U/min')
#l11=plt.plot(Bremsvorgangszeit11,Bremse_Drehzahl11,label='Versuch2 1500U/min')
#l12=plt.plot(Bremsvorgangszeit12,Bremse_Drehzahl12,label='Versuch3 1500U/min')
l1=plt.plot(Bremsvorgangszeit1,Bremsmoment1,label='Versuch 750U/min')
#l2=plt.plot(Bremsvorgangszeit2,Bremsmoment2,label='Versuch2 750U/min')
#l3=plt.plot(Bremsvorgangszeit3,Bremsmoment3,label='Versuch3 750U/min')
#l4=plt.plot(Bremsvorgangszeit4,Bremsmoment4,label='Versuch1 1000U/min')
#l5=plt.plot(Bremsvorgangszeit5,Bremsmoment5,label='Versuch2 1000U/min')
#l6=plt.plot(Bremsvorgangszeit6,Bremsmoment6,label='Versuch3 1000U/min')
#l7=plt.plot(Bremsvorgangszeit7,Bremsmoment7,label='Versuch1 1200U/min')
#l8=plt.plot(Bremsvorgangszeit8,Bremsmoment8,label='Versuch2 1200U/min')
#l9=plt.plot(Bremsvorgangszeit9,Bremsmoment9,label='Versuch3 1200U/min')
#l10=plt.plot(Bremsvorgangszeit10,Bremsmoment10,label='Versuch1 1500U/min')
#l11=plt.plot(Bremsvorgangszeit11,Bremsmoment11,label='Versuch2 1500U/min')
#l12=plt.plot(Bremsvorgangszeit12,Bremsmoment12,label='Versuch3 1500U/min')
#l1=plt.plot(Bremsvorgangszeit1,Zugkraft1,label='Versuch1 750U/min')
#l2=plt.plot(Bremsvorgangszeit2,Zugkraft2,label='Versuch2 750U/min')
#l3=plt.plot(Bremsvorgangszeit3,Zugkraft3,label='Versuch3 750U/min')
#l4=plt.plot(Bremsvorgangszeit4,Zugkraft4,label='Versuch1 1000U/min')
#l5=plt.plot(Bremsvorgangszeit5,Zugkraft5,label='Versuch2 1000U/min')
#l6=plt.plot(Bremsvorgangszeit6,Zugkraft6,label='Versuch3 1000U/min')
#l7=plt.plot(Bremsvorgangszeit7,Zugkraft7,label='Versuch1 1200U/min')
#l8=plt.plot(Bremsvorgangszeit8,Zugkraft8,label='Versuch2 1200U/min')
#l9=plt.plot(Bremsvorgangszeit9,Zugkraft9,label='Versuch3 1200U/min')
#l10=plt.plot(Bremsvorgangszeit10,Zugkraft10,label='Versuch1 1500U/min')
#l11=plt.plot(Bremsvorgangszeit11,Zugkraft11,label='Versuch2 1500U/min')
#l12=plt.plot(Bremsvorgangszeit12,Zugkraft12,label='Versuch3 1500U/min')
#plt.savefig('Versuch2_Bremse_Drehzahl')
plt.legend()
plt.show()

# %%
Bremse_Zeit1
Anfangszeit=np.ones(len(Bremse_Zeit1))*Zeit[Zeitpunktreihe[0]]
Bremsvorgangszeit=Bremse_Zeit1-Anfangszeit

# %%
Bremse_Zeit2=Zeit[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Anfangszeit2=np.ones(len(Bremse_Zeit2))*Zeit[Zeitpunktreihe[2]]
Bremsvorgangszeit2=Bremse_Zeit2-Anfangszeit2
Bremse_Drehzahl2=Drehzahl[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
plt.plot(Bremsvorgangszeit2,Bremse_Drehzahl2,'g+-')
plt.show()

# %%
Zeit=ergbs_Ver1[:,0]
Bremsmoment=ergbs_Ver1[:,1]
Zugkraft=ergbs_Ver1[:,2]
Drehzahl=ergbs_Ver1[:,4]
#Zeitpunkt=[13.550,14.200,69.560,70.180,101.755,102.390,146.865,147.680,180.250,181.075,214.420,215.265,252.640,253.670,286.650,287.620,319.625,320.660,357.145,358.335,393.595,394.835,427.975,429.265]
Zeitpunkt=[46.765,47.915,81.335,82.480,114.970,116.110,158.315,159.840,198.735,200.205,238.230,239.685,272.835,274.665,307.030,308.875,342.225,344.040,381.485,383.650,415.375,417.510,451.070,453.175]
j=0
Zeitpunktreihe=[]
for i in range(len(Zeit)):
    if Zeit[i]==Zeitpunkt[j]:
        Zeitpunktreihe.append(i)
        if j!=len(Zeitpunkt)-1:
            j+=1
Bremse_Zeit1=Zeit[Zeitpunktreihe[0]:Zeitpunktreihe[1]]
Anfangszeit1=np.ones(len(Bremse_Zeit1))*Zeit[Zeitpunktreihe[0]]
Bremsvorgangszeit1=Bremse_Zeit1-Anfangszeit1
Bremse_Drehzahl1=Drehzahl[Zeitpunktreihe[0]:Zeitpunktreihe[1]]
Bremsmoment1=Bremsmoment[Zeitpunktreihe[0]:Zeitpunktreihe[1]]
Zugkraft1=Zugkraft[Zeitpunktreihe[0]:Zeitpunktreihe[1]]

Bremse_Zeit2=Zeit[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Anfangszeit2=np.ones(len(Bremse_Zeit2))*Zeit[Zeitpunktreihe[2]]
Bremsvorgangszeit2=Bremse_Zeit2-Anfangszeit2
Bremse_Drehzahl2=Drehzahl[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Bremsmoment2=Bremsmoment[Zeitpunktreihe[2]:Zeitpunktreihe[3]]
Zugkraft2=Zugkraft[Zeitpunktreihe[2]:Zeitpunktreihe[3]]



Bremse_Zeit3=Zeit[Zeitpunktreihe[4]:Zeitpunktreihe[5]]
Anfangszeit3=np.ones(len(Bremse_Zeit3))*Zeit[Zeitpunktreihe[4]]
Bremsvorgangszeit3=Bremse_Zeit3-Anfangszeit3
Bremse_Drehzahl3=Drehzahl[Zeitpunktreihe[4]:Zeitpunktreihe[5]]
Bremsmoment3=Bremsmoment[Zeitpunktreihe[4]:Zeitpunktreihe[5]]
Zugkraft3=Zugkraft[Zeitpunktreihe[4]:Zeitpunktreihe[5]]

Bremse_Zeit4=Zeit[Zeitpunktreihe[6]:Zeitpunktreihe[7]]
Anfangszeit4=np.ones(len(Bremse_Zeit4))*Zeit[Zeitpunktreihe[6]]
Bremsvorgangszeit4=Bremse_Zeit4-Anfangszeit4
Bremse_Drehzahl4=Drehzahl[Zeitpunktreihe[6]:Zeitpunktreihe[7]]
Bremsmoment4=Bremsmoment[Zeitpunktreihe[6]:Zeitpunktreihe[7]]
Zugkraft4=Zugkraft[Zeitpunktreihe[6]:Zeitpunktreihe[7]]

Bremse_Zeit5=Zeit[Zeitpunktreihe[8]:Zeitpunktreihe[9]]
Anfangszeit5=np.ones(len(Bremse_Zeit5))*Zeit[Zeitpunktreihe[8]]
Bremsvorgangszeit5=Bremse_Zeit5-Anfangszeit5
Bremse_Drehzahl5=Drehzahl[Zeitpunktreihe[8]:Zeitpunktreihe[9]]
Bremsmoment5=Bremsmoment[Zeitpunktreihe[8]:Zeitpunktreihe[9]]
Zugkraft5=Zugkraft[Zeitpunktreihe[8]:Zeitpunktreihe[9]]

Bremse_Zeit6=Zeit[Zeitpunktreihe[10]:Zeitpunktreihe[11]]
Anfangszeit6=np.ones(len(Bremse_Zeit6))*Zeit[Zeitpunktreihe[10]]
Bremsvorgangszeit6=Bremse_Zeit6-Anfangszeit6
Bremse_Drehzahl6=Drehzahl[Zeitpunktreihe[10]:Zeitpunktreihe[11]]
Bremsmoment6=Bremsmoment[Zeitpunktreihe[10]:Zeitpunktreihe[11]]
Zugkraft6=Zugkraft[Zeitpunktreihe[10]:Zeitpunktreihe[11]]

Bremse_Zeit7=Zeit[Zeitpunktreihe[12]:Zeitpunktreihe[13]]
Anfangszeit7=np.ones(len(Bremse_Zeit7))*Zeit[Zeitpunktreihe[12]]
Bremsvorgangszeit7=Bremse_Zeit7-Anfangszeit7
Bremse_Drehzahl7=Drehzahl[Zeitpunktreihe[12]:Zeitpunktreihe[13]]
Bremsmoment7=Bremsmoment[Zeitpunktreihe[12]:Zeitpunktreihe[13]]
Zugkraft7=Zugkraft[Zeitpunktreihe[12]:Zeitpunktreihe[13]]

Bremse_Zeit8=Zeit[Zeitpunktreihe[14]:Zeitpunktreihe[15]]
Anfangszeit8=np.ones(len(Bremse_Zeit8))*Zeit[Zeitpunktreihe[14]]
Bremsvorgangszeit8=Bremse_Zeit8-Anfangszeit8
Bremse_Drehzahl8=Drehzahl[Zeitpunktreihe[14]:Zeitpunktreihe[15]]
Bremsmoment8=Bremsmoment[Zeitpunktreihe[14]:Zeitpunktreihe[15]]
Zugkraft8=Zugkraft[Zeitpunktreihe[14]:Zeitpunktreihe[15]]

Bremse_Zeit9=Zeit[Zeitpunktreihe[16]:Zeitpunktreihe[17]]
Anfangszeit9=np.ones(len(Bremse_Zeit9))*Zeit[Zeitpunktreihe[16]]
Bremsvorgangszeit9=Bremse_Zeit9-Anfangszeit9
Bremse_Drehzahl9=Drehzahl[Zeitpunktreihe[16]:Zeitpunktreihe[17]]
Bremsmoment9=Bremsmoment[Zeitpunktreihe[16]:Zeitpunktreihe[17]]
Zugkraft9=Zugkraft[Zeitpunktreihe[16]:Zeitpunktreihe[17]]

Bremse_Zeit10=Zeit[Zeitpunktreihe[18]:Zeitpunktreihe[19]]
Anfangszeit10=np.ones(len(Bremse_Zeit10))*Zeit[Zeitpunktreihe[18]]
Bremsvorgangszeit10=Bremse_Zeit10-Anfangszeit10
Bremse_Drehzahl10=Drehzahl[Zeitpunktreihe[18]:Zeitpunktreihe[19]]
Bremsmoment10=Bremsmoment[Zeitpunktreihe[18]:Zeitpunktreihe[19]]
Zugkraft10=Zugkraft[Zeitpunktreihe[18]:Zeitpunktreihe[19]]

Bremse_Zeit11=Zeit[Zeitpunktreihe[20]:Zeitpunktreihe[21]]
Anfangszeit11=np.ones(len(Bremse_Zeit11))*Zeit[Zeitpunktreihe[20]]
Bremsvorgangszeit11=Bremse_Zeit11-Anfangszeit11
Bremse_Drehzahl11=Drehzahl[Zeitpunktreihe[20]:Zeitpunktreihe[21]]
Bremsmoment11=Bremsmoment[Zeitpunktreihe[20]:Zeitpunktreihe[21]]
Zugkraft11=Zugkraft[Zeitpunktreihe[20]:Zeitpunktreihe[21]]

Bremse_Zeit12=Zeit[Zeitpunktreihe[22]:Zeitpunktreihe[23]]
Anfangszeit12=np.ones(len(Bremse_Zeit12))*Zeit[Zeitpunktreihe[22]]
Bremsvorgangszeit12=Bremse_Zeit12-Anfangszeit12
Bremse_Drehzahl12=Drehzahl[Zeitpunktreihe[22]:Zeitpunktreihe[23]]
Bremsmoment12=Bremsmoment[Zeitpunktreihe[22]:Zeitpunktreihe[23]]
Zugkraft12=Zugkraft[Zeitpunktreihe[22]:Zeitpunktreihe[23]]

# %%
Bremsmoment12.mean()
# Out:
# 0.07355813953488372

# %%
Mittel_zugkraft=np.array([Zugkraft1.mean(),Zugkraft2.mean(),Zugkraft3.mean(),Zugkraft4.mean(),Zugkraft5.mean(),Zugkraft6.mean(),Zugkraft7.mean(),Zugkraft8.mean(),Zugkraft9.mean(),Zugkraft10.mean(),Zugkraft11.mean(),Zugkraft12.mean()]).mean()

# %%
Mittel_zugkraft
# Out:
# 0.3382239267555003
